# %%
# !python /trains.py \
    --optimizer FESAM \
    --beta 0.9 \
    --lr 0.05 \
    --rho 0.1 \
    --T 0.05 \
    --cutout \
    --momentum 0.9 \
    --weight-decay 1e-3 \
    --datasets CIFAR10 \
    --arch ResNet18 \
    --epochs 200 \
    --batch-size 128
# Out:
# save dir: save_temp
# log dir: save_temp
# Model: ResNet18
# cutout: True
# cutout!
# cifar10 dataset!
# 391
# 50000
# optimizer: FESAM
# FESAM (
# Parameter Group 0
#     T: 0.05
#     adaptive: False
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.05
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     rho: 0.1
#     weight_decay: 0.001
# )
# Start training:  0 -> 200
# current lr 5.00000e-02
# Epoch: [0][0/391]	Time 0.975 (0.975)	Data 0.126 (0.126)	Loss 2.4557 (2.4557)	Prec@1 15.625 (15.625)
# Epoch: [0][100/391]	Time 0.039 (0.049)	Data 0.000 (0.001)	Loss 1.7951 (2.2710)	Prec@1 32.031 (20.382)
# Epoch: [0][200/391]	Time 0.039 (0.044)	Data 0.000 (0.001)	Loss 1.8987 (2.0631)	Prec@1 32.031 (25.560)
# Epoch: [0][300/391]	Time 0.039 (0.043)	Data 0.000 (0.001)	Loss 1.5742 (1.9509)	Prec@1 46.875 (29.018)
# Epoch: [0][390/391]	Time 0.209 (0.043)	Data 0.000 (0.001)	Loss 1.6541 (1.8751)	Prec@1 43.750 (31.634)
# ...
